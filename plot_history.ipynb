# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/'
categories = ['books', 'dvd', 'electronics', 'kitchen_&_housewares', 'all']

# %% [markdown]
# ### books
# 1600 train, 400 test <br>
# 100 epochs <br>
# max_length = 200, embedding_dim = 50

# %%
history = pd.read_csv('/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/books/keras_history.csv')
epochs = np.arange(len(history))+1

# %%
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.7225 at epoch 94

# %% [markdown]
# ### books
# 1600 train, 400 test <br>
# 1000 epochs <br>
# max_length = 200, embedding_dim = 250<br>
# no Regularization

# %%
history = pd.read_csv(datapath + 'books/keras_embedDim250_noRegularization_1000eps/keras_history.csv')
epochs = np.arange(len(history))+1

# %%
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.6825 at epoch 23

# %% [markdown]
# ### books
# 1600 train, 400 test <br>
# 1000 epochs <br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.5)<br>
# no LSTM Regularization

# %%
history = pd.read_csv(datapath + 'books/keras_embedDim250_noLSTMRegularization_200eps/keras_history.csv')
epochs = np.arange(len(history))+1

# %%
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.7450 at epoch 42

# %% [markdown]
# ### books
# 1600 train, 400 test <br>
# 400 epochs <br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.5)<br>
# LSTM Regularization: input=0.5, recurrent=0.1

# %%
history = pd.read_csv(datapath + 'books/keras_embedDim250_FullRegularization_400eps/keras_history.csv')
epochs = np.arange(len(history))+1

# %%
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.7475 at epoch 348

# %% [markdown]
# ### all
# 250 epochs <br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.5)<br>
# LSTM Regularization: input=0.5, recurrent=0.1

# %%
history = pd.read_csv(datapath + 'all/keras_embedDim250_250eps/keras_history.csv')
epochs = np.arange(len(history))+1

# %%
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.8137 at epoch 233

# %% [markdown]
# ### books
# 200 epochs <br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.5)<br>
# LSTM Regularization: input=0.5, recurrent=0.5

# %%
history = pd.read_csv(datapath + 'books/keras_embedDim250_FullRegularization_dropoutU0.5_200eps/keras_history.csv')
epochs = np.arange(len(history))+1

# %%
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.6900 at epoch 145

# %% [markdown]
# ### all categories
# 1000 epochs <br>
# batch_size = 32 (as in previous experiments)<br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3

# %%
settings = 'embedDim250_FullRegularization_1000eps'

for category in categories:
    print '\ncategory: ' + category
    history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history.csv')
    epochs = np.arange(len(history))+1
    
    plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
    plt.ylim([0,1])
    plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
    plt.show()
    print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# category: books
# Maximum test accuracy is 0.7525 at epoch 774
#
# category: dvd
# Maximum test accuracy is 0.8150 at epoch 801
#
# category: electronics
# Maximum test accuracy is 0.8800 at epoch 539
#
# category: kitchen_&_housewares
# Maximum test accuracy is 0.8675 at epoch 860
#
# category: all
# Maximum test accuracy is 0.8781 at epoch 240

# %% [markdown]
# ### books
# 1000 epochs <br>
# batch_size = 128<br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3

# %%
settings = 'embedDim250_FullRegularization_batchSize128_1000eps'
category = 'books'

history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history.csv')
epochs = np.arange(len(history))+1
    
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.7425 at epoch 323

# %% [markdown]
# ### books
# 1000 epochs <br>
# batch_size = 64<br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3

# %%
settings = 'embedDim250_FullRegularization_batchSize64_1000eps'
category = 'books'

history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history.csv')
epochs = np.arange(len(history))+1
    
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.7275 at epoch 143

# %% [markdown]
# ### books
# 1000 epochs <br>
# batch_size = 32<br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3<br>
# learning rate = 1e-6 (was 1e-4 before)

# %%
settings = 'embedDim250_FullRegularization_lr1e-6_1000eps'
category = 'books'

history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history.csv')
epochs = np.arange(len(history))+1
    
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.4925 at epoch 960

# %% [markdown]
# ### all categories
# 1000 epochs <br>
# batch_size = 32 (as in previous experiments)<br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3<br>
# use eos tags to show the end of a sentence. fill unknown words with zeros

# %%
settings = 'embedDim250_FullRegularization_eosTag_1000eps'

for category in categories:
    print '\ncategory: ' + category
    history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history2.csv')
    epochs = np.arange(len(history))+1
    
    plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
    plt.ylim([0,1])
    plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
    plt.show()
    print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# category: books
# Maximum test accuracy is 0.7300 at epoch 945
#
# category: dvd
# Maximum test accuracy is 0.8075 at epoch 712
#
# category: electronics
# Maximum test accuracy is 0.8775 at epoch 829
#
# category: kitchen_&_housewares
# Maximum test accuracy is 0.8425 at epoch 763
#
# category: all
# Maximum test accuracy is 0.8838 at epoch 558

# %% [markdown]
# ### books, electronics, kitchen & housewares
# large dataset: 19800 reviews per category<br>
# 300 epochs <br>
# batch_size = 32 (as in previous experiments)<br>
# max_length = 200, embedding_dim = 250<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3<br>
# use eos tags to show the end of a sentence. fill unknown words with zeros

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data/'
categories = ['books', 'electronics', 'kitchen_&_housewares']

settings = 'embedDim250_eosTag_300eps'

for category in categories:
    print '\ncategory: ' + category
    history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history2.csv')
    epochs = np.arange(len(history))+1
    
    plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
    plt.ylim([0,1])
    plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
    plt.show()
    print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# category: books
# Maximum test accuracy is 0.9212 at epoch 284
#
# category: electronics
# Maximum test accuracy is 0.9379 at epoch 285
#
# category: kitchen_&_housewares
# Maximum test accuracy is 0.9424 at epoch 259

# %% [markdown]
# ### all
# large dataset: 19800 reviews per category<br>
# 53 epochs <br>
# batch_size = 32<br>
# max_length = 200, embedding_dim = 250<br>
# with weighted Embedding layer<br>
# no dropout at Embedding layer<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3<br>
# use eos tags to show the end of a sentence. fill unknown words with zeros

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data/'
settings = 'embedDim250_embeddingLayer_noDropout_53eps'
category = 'all'

history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history2.csv')
epochs = np.arange(len(history))+1
    
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# Maximum test accuracy is 0.9396 at epoch 21

# %% [markdown]
# ### all categories
# large dataset: 19800 reviews per category<br>
# 35 epochs <br>
# batch_size = 32<br>
# max_length = 200, embedding_dim = 250<br>
# with weighted Embedding layer<br>
# no dropout at Embedding layer<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3<br>
# use eos tags to show the end of a sentence. fill unknown words with zeros

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data/'
categories = ['books', 'dvd', 'electronics', 'kitchen_&_housewares', 'all']

settings = 'embedDim250_embeddingLayer_noDropout_35eps'

for category in categories:
    print '\ncategory: ' + category
    history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history.csv')
    epochs = np.arange(len(history))+1
    
    plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
    plt.ylim([0,1])
    plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
    plt.show()
    print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# category: books
# Maximum test accuracy is 0.9293 at epoch 18
#
# category: dvd
# Maximum test accuracy is 0.9285 at epoch 29
#
# category: electronics
# Maximum test accuracy is 0.9376 at epoch 15
#
# category: kitchen_&_housewares
# Maximum test accuracy is 0.9452 at epoch 18
#
# category: all
# Maximum test accuracy is 0.9395 at epoch 11

# %% [markdown]
# ### all categories
# large dataset: 19800 reviews per category<br>
# 150 epochs <br>
# batch_size = 32<br>
# max_length = 200, embedding_dim = 250<br>
# with weighted Embedding layer<br>
# dropout at Embedding layer = 0.5<br>
# Dropout layer (dropout = 0.8)<br>
# LSTM Regularization: input=0.5, recurrent=0.3<br>
# use eos tags to show the end of a sentence. fill unknown words with zeros

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data/'
categories = ['books', 'dvd', 'electronics', 'kitchen_&_housewares', 'all']

settings = 'embedDim250_embeddingLayer_150eps'

for category in categories:
    print '\ncategory: ' + category
    history = pd.read_csv(datapath + category +'/keras_' + settings + '/keras_history.csv')
    epochs = np.arange(len(history))+1
    
    plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
         epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
    plt.ylim([0,1])
    plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
    plt.show()
    print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))
# Out:
# category: books
# Maximum test accuracy is 0.9303 at epoch 42
#
# category: dvd
# Maximum test accuracy is 0.9308 at epoch 41
#
# category: electronics
# Maximum test accuracy is 0.9346 at epoch 131
#
# category: kitchen_&_housewares
# Maximum test accuracy is 0.9424 at epoch 39
#
# category: all
# Maximum test accuracy is 0.9289 at epoch 52
