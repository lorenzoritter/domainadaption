# %% [markdown]
# # v5: Use Embedding layer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_history(history):
    epochs = np.arange(len(history))+1
    plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
             epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
    plt.ylim([0,1])
    plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
    plt.show()
    print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))

# %% [markdown]
# ### Setup:
# keras 1.0.3
#
# prior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer static
#
# posterior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer trainable, no Dropout

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/'
categories = ['books', 'dvd', 'electronics', 'kitchen']
setting_prior = ''
setting_posterior = 'noEmbeddingDropout'

print 'prior: all'
prior_history = pd.read_csv(datapath + 'all/v5/keras_' + setting_prior + '/keras_history.csv')
plot_history(prior_history)

print '\nposterior'
for category in categories:
    print '\ncategory: ' + category
    posterior_history = pd.read_csv(datapath + category +'/v5/keras_' + setting_posterior + '/keras_history.csv')
    plot_history(posterior_history)
    
import evaluate_prior_posterior_v5
evaluate_prior_posterior_v5.evaluate_prior(setting_prior)
evaluate_prior_posterior_v5.evaluate_posterior(setting_posterior)
# Out:
# prior: all
# Maximum test accuracy is 0.8744 at epoch 195
#
# posterior
#
# category: books
# Maximum test accuracy is 0.8512 at epoch 29
#
# category: dvd
# Maximum test accuracy is 0.8475 at epoch 11
#
# category: electronics
# Maximum test accuracy is 0.8875 at epoch 11
#
# category: kitchen
# Maximum test accuracy is 0.9175 at epoch 20
# Using Theano backend.
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 45.0% of memory, cuDNN 5004)
# Evaluating prior...
#
# category: books
# Evaluate training data...
# 	train loss: 0.0192
# 	train accuracy: 0.9958
# Evaluate test data...
# 	test loss: 0.6072
# 	test accuracy: 0.8300
#
# category: dvd
# Evaluate training data...
# 	train loss: 0.0137
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.6916
# 	test accuracy: 0.8413
#
# category: electronics
# Evaluate training data...
# 	train loss: 0.0089
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.4740
# 	test accuracy: 0.8812
# ...

# %% [markdown]
# ### Setup:
# keras 1.0.3
#
# prior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer static
#
# posterior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer trainable, Dropout=0.5

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/'
categories = ['books', 'dvd', 'electronics', 'kitchen']
setting_prior = ''
setting_posterior = ''

print 'prior: all'
prior_history = pd.read_csv(datapath + 'all/v5/keras_' + setting_prior + '/keras_history.csv')
plot_history(prior_history)

print '\nposterior'
for category in categories:
    print '\ncategory: ' + category
    posterior_history = pd.read_csv(datapath + category +'/v5/keras_' + setting_posterior + '/keras_history.csv')
    plot_history(posterior_history)
    
import evaluate_prior_posterior_v5
evaluate_prior_posterior_v5.evaluate_prior(setting_prior)
evaluate_prior_posterior_v5.evaluate_posterior(setting_posterior)
# Out:
# prior: all
# Maximum test accuracy is 0.8744 at epoch 195
#
# posterior
#
# category: books
# Maximum test accuracy is 0.8650 at epoch 15
#
# category: dvd
# Maximum test accuracy is 0.8512 at epoch 15
#
# category: electronics
# Maximum test accuracy is 0.8912 at epoch 3
#
# category: kitchen
# Maximum test accuracy is 0.9200 at epoch 32
#
# Evaluating prior...
#
# category: books
# Evaluate training data...
# 	train loss: 0.0192
# 	train accuracy: 0.9958
# Evaluate test data...
# 	test loss: 0.6072
# 	test accuracy: 0.8300
#
# category: dvd
# Evaluate training data...
# 	train loss: 0.0137
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.6916
# 	test accuracy: 0.8413
#
# category: electronics
# Evaluate training data...
# 	train loss: 0.0089
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.4740
# 	test accuracy: 0.8812
#
# category: kitchen
# Evaluate training data...
# 	train loss: 0.0077
# 	train accuracy: 0.9992
# Evaluate test data...
# ...

# %% [markdown]
# ### Setup:
# keras 1.0.3
#
# prior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer static
#
# posterior:
#   * optimizer=RMSProp(lr=1e-4, epsilon=1e-8)
#   * Embedding layer trainable, Dropout=0.5

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/'
categories = ['books', 'dvd', 'electronics', 'kitchen']
setting_prior = ''
setting_posterior = 'lr0.0001' # check whether the 1e-4 is really written in exponenial form

print 'prior: all'
prior_history = pd.read_csv(datapath + 'all/v5/keras_' + setting_prior + '/keras_history.csv')
plot_history(prior_history)

print '\nposterior'
for category in categories:
    print '\ncategory: ' + category
    posterior_history = pd.read_csv(datapath + category +'/v5/keras_' + setting_posterior + '/keras_history.csv')
    plot_history(posterior_history)
    
import evaluate_prior_posterior_v5
evaluate_prior_posterior_v5.evaluate_prior(setting_prior)
evaluate_prior_posterior_v5.evaluate_posterior(setting_posterior)
# Out:
# prior: all
# Maximum test accuracy is 0.8744 at epoch 195
#
# posterior
#
# category: books
# Maximum test accuracy is 0.8612 at epoch 31
#
# category: dvd
# Maximum test accuracy is 0.8512 at epoch 20
#
# category: electronics
# Maximum test accuracy is 0.8962 at epoch 18
#
# category: kitchen
# Maximum test accuracy is 0.9263 at epoch 35
# Using Theano backend.
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 45.0% of memory, cuDNN 5004)
# Evaluating prior...
#
# category: books
# Evaluate training data...
# 	train loss: 0.0192
# 	train accuracy: 0.9958
# Evaluate test data...
# 	test loss: 0.6072
# 	test accuracy: 0.8300
#
# category: dvd
# Evaluate training data...
# 	train loss: 0.0137
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.6916
# 	test accuracy: 0.8413
#
# category: electronics
# Evaluate training data...
# 	train loss: 0.0089
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.4740
# 	test accuracy: 0.8812
# ...

# %% [markdown]
# ### Setup:
# keras 1.0.3
#
# prior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer static
#
# posterior:
#   * optimizer=RMSProp(lr=1e-5, epsilon=1e-8)
#   * Embedding layer trainable, Dropout=0.5

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/'
categories = ['books', 'dvd', 'electronics', 'kitchen']
setting_prior = ''
setting_posterior = 'lr1e-05'

print 'prior: all'
prior_history = pd.read_csv(datapath + 'all/v5/keras_' + setting_prior + '/keras_history.csv')
plot_history(prior_history)

print '\nposterior'
for category in categories:
    print '\ncategory: ' + category
    posterior_history = pd.read_csv(datapath + category +'/v5/keras_' + setting_posterior + '/keras_history.csv')
    plot_history(posterior_history)
    
import evaluate_prior_posterior_v5
evaluate_prior_posterior_v5.evaluate_prior(setting_prior)
evaluate_prior_posterior_v5.evaluate_posterior(setting_posterior)
# Out:
# prior: all
# Maximum test accuracy is 0.8744 at epoch 195
#
# posterior
#
# category: books
# Maximum test accuracy is 0.8725 at epoch 41
#
# category: dvd
# Maximum test accuracy is 0.8488 at epoch 8
#
# category: electronics
# Maximum test accuracy is 0.8912 at epoch 146
#
# category: kitchen
# Maximum test accuracy is 0.9187 at epoch 37
#
# Evaluating prior...
#
# category: books
# Evaluate training data...
# 	train loss: 0.0192
# 	train accuracy: 0.9958
# Evaluate test data...
# 	test loss: 0.6072
# 	test accuracy: 0.8300
#
# category: dvd
# Evaluate training data...
# 	train loss: 0.0137
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.6916
# 	test accuracy: 0.8413
#
# category: electronics
# Evaluate training data...
# 	train loss: 0.0089
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.4740
# 	test accuracy: 0.8812
#
# category: kitchen
# Evaluate training data...
# 	train loss: 0.0077
# 	train accuracy: 0.9992
# Evaluate test data...
# ...

# %% [markdown]
# ### Setup:
# keras 1.0.3
#
# prior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer static
#
# posterior:
#   * optimizer=RMSProp(lr=1e-6, epsilon=1e-8)
#   * Embedding layer trainable, Dropout=0.5

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/'
categories = ['books', 'dvd', 'electronics', 'kitchen']
setting_prior = ''
setting_posterior = 'lr1e-06'

print 'prior: all'
prior_history = pd.read_csv(datapath + 'all/v5/keras_' + setting_prior + '/keras_history.csv')
plot_history(prior_history)

print '\nposterior'
for category in categories:
    print '\ncategory: ' + category
    posterior_history = pd.read_csv(datapath + category +'/v5/keras_' + setting_posterior + '/keras_history.csv')
    plot_history(posterior_history)
    
import evaluate_prior_posterior_v5
evaluate_prior_posterior_v5.evaluate_prior(setting_prior)
evaluate_prior_posterior_v5.evaluate_posterior(setting_posterior)
# Out:
# prior: all
# Maximum test accuracy is 0.8744 at epoch 195
#
# posterior
#
# category: books
# Maximum test accuracy is 0.8662 at epoch 30
#
# category: dvd
# Maximum test accuracy is 0.8538 at epoch 14
#
# category: electronics
# Maximum test accuracy is 0.8900 at epoch 8
#
# category: kitchen
# Maximum test accuracy is 0.9263 at epoch 40
#
# Evaluating prior...
#
# category: books
# Evaluate training data...
# 	train loss: 0.0192
# 	train accuracy: 0.9958
# Evaluate test data...
# 	test loss: 0.6072
# 	test accuracy: 0.8300
#
# category: dvd
# Evaluate training data...
# 	train loss: 0.0137
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.6916
# 	test accuracy: 0.8413
#
# category: electronics
# Evaluate training data...
# 	train loss: 0.0089
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.4740
# 	test accuracy: 0.8812
#
# category: kitchen
# Evaluate training data...
# 	train loss: 0.0077
# 	train accuracy: 0.9992
# Evaluate test data...
# ...

# %% [markdown]
# ### Setup:
# keras 1.0.3
#
# prior:
#   * optimizer=RMSProp(lr=1e-3, epsilon=1e-8) # default
#   * Embedding layer static
#
# posterior:
#   * optimizer=RMSProp(lr=1e-7, epsilon=1e-8)
#   * Embedding layer trainable, Dropout=0.5

# %%
datapath = '/home/lorenzo/PycharmProjects/domainadaption/sorted_data_acl/'
categories = ['books', 'dvd', 'electronics', 'kitchen']
setting_prior = ''
setting_posterior = 'lr1e-07'

print 'prior: all'
prior_history = pd.read_csv(datapath + 'all/v5/keras_' + setting_prior + '/keras_history.csv')
plot_history(prior_history)

print '\nposterior'
for category in categories:
    print '\ncategory: ' + category
    posterior_history = pd.read_csv(datapath + category +'/v5/keras_' + setting_posterior + '/keras_history.csv')
    plot_history(posterior_history)
    
import evaluate_prior_posterior_v5
evaluate_prior_posterior_v5.evaluate_prior(setting_prior)
evaluate_prior_posterior_v5.evaluate_posterior(setting_posterior)
# Out:
# prior: all
# Maximum test accuracy is 0.8744 at epoch 195
#
# posterior
#
# category: books
# Maximum test accuracy is 0.8638 at epoch 42
#
# category: dvd
# Maximum test accuracy is 0.8475 at epoch 2
#
# category: electronics
# Maximum test accuracy is 0.8900 at epoch 12
#
# category: kitchen
# Maximum test accuracy is 0.9213 at epoch 39
#
# Evaluating prior...
#
# category: books
# Evaluate training data...
# 	train loss: 0.0192
# 	train accuracy: 0.9958
# Evaluate test data...
# 	test loss: 0.6072
# 	test accuracy: 0.8300
#
# category: dvd
# Evaluate training data...
# 	train loss: 0.0137
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.6916
# 	test accuracy: 0.8413
#
# category: electronics
# Evaluate training data...
# 	train loss: 0.0089
# 	train accuracy: 0.9992
# Evaluate test data...
# 	test loss: 0.4740
# 	test accuracy: 0.8812
#
# category: kitchen
# Evaluate training data...
# 	train loss: 0.0077
# 	train accuracy: 0.9992
# Evaluate test data...
# ...
