# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datapath = '/home/zhaoxu/venv/sentiment/exp/'

#categories = ['books', 'dvd', 'electronics', 'kitchen'] # kitchen_&_housewares
#for category in categories:

category = 'dvd'
print '\ncategory: ' + category

history = pd.read_csv(datapath + category +'/hdl/prior_keras_history.csv')
epochs = np.arange(len(history))+1
    
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
     epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))


history = pd.read_csv(datapath + category +'/hdl/posterior_keras_history.csv')
epochs = np.arange(len(history))+1
    
plt.plot(epochs, history['val_loss'], 'b', epochs, history['loss'], 'b--', 
     epochs, history['val_acc'], 'r', epochs, history['acc'], 'r--')
plt.ylim([0,1])
plt.legend(['loss (testing)', 'loss (training)', 'accuracy (testing)', 'accuracy (training)'], bbox_to_anchor=(1.55, 1))
plt.show()
print('Maximum test accuracy is %0.4f at epoch %i' %(max(history.val_acc), np.argmax(history.val_acc)+1))

import predict_with_learned_models as plm
print plm.run(category)
# Out:
# category: dvd
# Maximum test accuracy is 0.9800 at epoch 185
# Maximum test accuracy is 0.9950 at epoch 2
# Train posterior for the category: dvd
# Loading data...
# 1600 train sequences
# 400 test sequences
# maxlen: 200
# embedding_dim: 250
#
# Builing model...
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# lstm_2 (LSTM)                      (None, 50)          60200       lstm_input_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 50)          0           lstm_2[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 1)           51          dropout_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)          (None, 1)           0           dense_2[0][0]
# ====================================================================================================
# Total params: 60251
# ____________________________________________________________________________________________________
# Compiling model...
# Evaluating model...
# 1600/1600 [==============================] - 3s
# Train score: 0.063096
# Train accuracy: 0.981250
# 400/400 [==============================] - 0s
# Test score: 0.043093
# Test accuracy: 0.985000
# Runtime: 0:00:08.296689
# (0.063096421854570511, 0.98124999999999996, 0.043093168549239634, 0.98499999999999999)
